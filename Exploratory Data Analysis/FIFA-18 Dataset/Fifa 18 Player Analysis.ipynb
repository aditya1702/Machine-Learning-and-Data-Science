# %%
library(tidyverse)
library(moments)

# %% [markdown]
# ## **Reading the data**

# %%
df <- read_csv("fifa18.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   ID = col_integer(),
#   special = col_integer(),
#   age = col_integer(),
#   birth_date = col_date(format = ""),
#   height_cm = col_double(),
#   weight_kg = col_double(),
#   eur_value = col_double(),
#   eur_wage = col_double(),
#   eur_release_clause = col_double(),
#   overall = col_integer(),
#   potential = col_integer(),
#   pac = col_integer(),
#   sho = col_integer(),
#   pas = col_integer(),
#   dri = col_integer(),
#   def = col_integer(),
#   phy = col_integer(),
#   international_reputation = col_integer(),
#   skill_moves = col_integer(),
#   weak_foot = col_integer()
#   # ... with 61 more columns
# )
# See spec(...) for full column specifications.

# %%
head(df)
# Out:
# Warning message in format.POSIXlt(as.POSIXlt(x), ...):
# “unknown timezone 'zone/tz/2018c.1.0/zoneinfo/Asia/Kolkata'”
#   ID     name              full_name                    club
# 1  20801 Cristiano Ronaldo C. Ronaldo dos Santos Aveiro Real Madrid CF
# 2 158023 L. Messi          Lionel Messi                 FC Barcelona
# 3 190871 Neymar            Neymar da Silva Santos Jr.   Paris Saint-Germain
# 4 176580 L. Suárez         Luis Suárez                  FC Barcelona
# 5 167495 M. Neuer          Manuel Neuer                 FC Bayern Munich
# 6 188545 R. Lewandowski    Robert Lewandowski           FC Bayern Munich
#   club_logo                               special age league
# 1 https://cdn.sofifa.org/18/teams/243.png 2228    32  Spanish Primera División
# 2 https://cdn.sofifa.org/18/teams/241.png 2158    30  Spanish Primera División
# 3 https://cdn.sofifa.org/18/teams/73.png  2100    25  French Ligue 1
# ...

# %%
glimpse(df)
# Out:
# Observations: 17,994
# Variables: 185
# $ ID                                 <int> 20801, 158023, 190871, 176580, 1...
# $ name                               <chr> "Cristiano Ronaldo", "L. Messi",...
# $ full_name                          <chr> "C. Ronaldo dos Santos Aveiro", ...
# $ club                               <chr> "Real Madrid CF", "FC Barcelona"...
# $ club_logo                          <chr> "https://cdn.sofifa.org/18/teams...
# $ special                            <int> 2228, 2158, 2100, 2291, 1493, 21...
# $ age                                <int> 32, 30, 25, 30, 31, 28, 26, 26, ...
# $ league                             <chr> "Spanish Primera División", "Spa...
# $ birth_date                         <date> 1985-02-05, 1987-06-24, 1992-02...
# $ height_cm                          <dbl> 185, 170, 175, 182, 193, 185, 19...
# $ weight_kg                          <dbl> 80, 72, 68, 86, 92, 79, 76, 76, ...
# ...
